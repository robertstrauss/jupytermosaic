# %% [markdown]
# # big
# ## also big
# ### slightly smaller
# #### smaller
#
# text text text

# %%
def codefunc(argument):
    return argument+1

# %%
codefunc(3)
# Out:
# 4

# %%
codefunc('a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-e27b53b76b2f> in <module>
# ----> 1 codefunc('a')
#
# <ipython-input-1-8a3f9f37fb83> in codefunc(argument)
#       1 def codefunc(argument):
# ----> 2     return argument+1
#
# TypeError: can only concatenate str (not "int") to str

# %%
codefunc?
# Out:
# Signature: codefunc(argument)
# Docstring: <no docstring>
# File:      ~/Desktop/jupyter-mosaic/jupytermosaic/<ipython-input-1-8a3f9f37fb83>
# Type:      function

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'quit']

# %%
dir(quit)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_ip',
#  'rewrite',
#  'set_ip']

# %%
quit?
# Out:
# Signature: quit()
# Docstring: <no docstring>
# File:      ~/Desktop/jupyter-mosaic/jupytermosaic/<ipython-input-4-7111f5065284>
# Type:      function

# %%
def quit():
    print ('Fuck you!')

# %%
quit()
# Out:
# Fuck you!

# %%
quit.__globals__
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'dir()',
#   'dir(quit)',
#   "get_ipython().run_line_magic('pinfo', 'quit')",
#   "def quit():\n    print ('Fuck you!')",
#   "get_ipython().run_line_magic('pinfo', 'quit')",
#   'quit.__file__',
#   "get_ipython().run_line_magic('pinfo', 'quit')",
#   'dir(quit)',
#   "quit.__globals__['__file__']",
#   'quit.__globals__',
#   'quit.__module__',
#   'quit.__module__.__globals__',
#   'quit.__globals__',
#   "quit.__globals__['quit.__file__']",
#   'quit.__globals__',
#   'quit.__globals__'],
#  '_oh': {1: ['In',
#    'Out',
#    '_',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
# ...
